# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data from card_transdata.csv
data = pd.read_csv('card_transdata.csv')

# %%
#Get length of the data
print(f'Number of rows = {len(data)}')

# Get number of columns in data
print(f'Number of columns = {len(data.columns)}\n')

# Get the data types of the columns
print('Column names and types:')
print(data.dtypes)
# Out:
# Number of rows = 1000000
# Number of columns = 8
#
# Column names and types:
# distance_from_home                float64
# distance_from_last_transaction    float64
# ratio_to_median_purchase_price    float64
# repeat_retailer                   float64
# used_chip                         float64
# used_pin_number                   float64
# online_order                      float64
# fraud                             float64
# dtype: object

# %%
data.describe()
# Out:
#        distance_from_home  distance_from_last_transaction  \
# count      1000000.000000                  1000000.000000
# mean            26.628792                        5.036519
# std             65.390784                       25.843093
# min              0.004874                        0.000118
# 25%              3.878008                        0.296671
# 50%              9.967760                        0.998650
# 75%             25.743985                        3.355748
# max          10632.723672                    11851.104565
#
#        ratio_to_median_purchase_price  repeat_retailer       used_chip  \
# count                  1000000.000000   1000000.000000  1000000.000000
# mean                         1.824182         0.881536        0.350399
# std                          2.799589         0.323157        0.477095
# min                          0.004399         0.000000        0.000000
# 25%                          0.475673         1.000000        0.000000
# ...

# %% [markdown]
# # Vizualisations
# ## Fraud

# %%
# Get the percentage of fraud transactions
# print(f'Percentage of fraud transactions = {round(len(data[data["fraud"] == 1]) / len(data) * 100, 2)}%')
# print(f'Percentage of non-fraud transactions = {round(len(data[data["fraud"] == 0]) / len(data) * 100, 2)}%')
data['fraud'].value_counts().plot(kind='pie', autopct='%1.2f%%', colors = ['#0964ff','#fd79a8'], labels=['Non-Fraud', 'Fraud'])
plt.show()

# %% [markdown]
# ## Distance From Home

# %%
_, ax = plt.subplots(1,3, figsize=(18,5))
ax[0].set_title('Box plot without outliers')
ax[1].set_title('Box plot with outliers')
ax[2].set_title('Scatter plot')
data.boxplot(column='distance_from_home', showmeans = True, meanline = True, sym='', ax=ax[0])
data.boxplot(column='distance_from_home', showmeans = True, meanline = True, ax=ax[1])
data.plot.scatter(y='distance_from_home', x='fraud', ax=ax[2])
plt.show()
# Out:
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Ditsance From Last Transaction

# %%
_, ax = plt.subplots(1,3, figsize=(18,5))
ax[0].set_title('Box plot without outliers')
ax[1].set_title('Box plot with outliers')
ax[2].set_title('Scatter plot')
data.boxplot(column='distance_from_last_transaction', showmeans = True, meanline = True, sym='', ax=ax[0])
data.boxplot(column='distance_from_last_transaction', showmeans = True, meanline = True, ax=ax[1])
data.plot.scatter(y='distance_from_last_transaction', x='fraud', ax=ax[2])
plt.show()
# Out:
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Ratio to Median Purchase Price

# %%
_, ax = plt.subplots(1,3, figsize=(18,5))
ax[0].set_title('Box plot without outliers')
ax[1].set_title('Box plot with outliers')
ax[2].set_title('Scatter plot')
data.boxplot(column='ratio_to_median_purchase_price', showmeans = True, meanline = True, sym='', ax=ax[0])
data.boxplot(column='ratio_to_median_purchase_price', showmeans = True, meanline = True, ax=ax[1])
data.plot.scatter(y='ratio_to_median_purchase_price', x='fraud', ax=ax[2])
plt.show()
# Out:
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Categorical Features

# %%
_, ax = plt.subplots(2,2, figsize=(14,8))
ax[0,0].set_title('Repeat retailer')
ax[0,1].set_title('Used chip')
ax[1,0].set_title('Used pin number')
ax[1,1].set_title('Online order')
data['repeat_retailer'].value_counts().plot(kind='bar', color = ['#0964ff','#fd79a8'], ax=ax[0,0])
data['used_chip'].value_counts().plot(kind='bar', color = ['#0964ff','#fd79a8'], ax=ax[0,1])
data['used_pin_number'].value_counts().plot(kind='bar', color = ['#0964ff','#fd79a8'], ax=ax[1,0])
data['online_order'].value_counts().plot(kind='bar', color = ['#0964ff','#fd79a8'], ax=ax[1,1])
plt.show()

# %%
def plotting(df : pd.DataFrame, col : str):
    df.plot.density(y=col)
    df.plot.scatter(x=col, y="fraud")
    print(f"Column = {col} : \n{df[col].describe()}")

# %%
for col in data.columns:
    plotting(data, col)
# Out:
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Column = distance_from_home :
# count    1000000.000000
# mean          26.628792
# std           65.390784
# min            0.004874
# 25%            3.878008
# 50%            9.967760
# 75%           25.743985
# max        10632.723672
# Name: distance_from_home, dtype: float64
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Column = distance_from_last_transaction :
# count    1000000.000000
# mean           5.036519
# std           25.843093
# min            0.000118
# 25%            0.296671
# 50%            0.998650
# 75%            3.355748
# max        11851.104565
# ...
